# %% [markdown]
# <a href="https://colab.research.google.com/github/mymess/Bitcoin-nodes-globe/blob/master/Housing_Prices_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
# %matplotlib inline
import os
import tarfile
import pandas as pd
import matplotlib.pyplot as plt

from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
LOCAL_PATH    = os.path.join("datasets/housing")
DATA_URL      = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"
FILENAME      = "housing.csv"

class DataFetcher:

    def __init__(self, url, local_path, filename):
        self.url = url
        self.local_path = local_path
        self.filename = filename
        #self.fetch_data()



    def fetch_data(self):
        if not os.path.isdir(self.local_path ):
            os.makedirs( self.local_path )

        tgz_path = os.path.join(self.local_path, self.filename)
        print( "\nDownloading '" + self.url + "' to " + tgz_path);
        urllib.request.urlretrieve(self.url, tgz_path)
        tgz_file = tarfile.open(tgz_path)
        tgz_file.extractall(path=self.local_path)
        tgz_file.close()


    def load_data(self):
        csv_path = os.path.join(self.local_path, self.filename)
        return pd.read_csv(csv_path, error_bad_lines=False)

df = DataFetcher( DATA_URL, LOCAL_PATH, FILENAME);
df.fetch_data()

housing_dataframe = df.load_data()
print( housing_dataframe.head() )

#print (os.path.join(LOCAL_PATH, FILENAME));

housing_dataframe = df.load_data()
#housing_dataframe.dropna();
print( housing_dataframe.head() )

housing_dataframe.hist(bins=50, figsize=(20, 15))


plt.show()
# Out:
# Downloading 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz' to datasets/housing/housing.csv
#   longitude latitude housing_median_age total_rooms total_bedrooms population  \
# 0   -122.23    37.88               41.0       880.0          129.0      322.0
# 1   -122.22    37.86               21.0      7099.0         1106.0     2401.0
# 2   -122.24    37.85               52.0      1467.0          190.0      496.0
# 3   -122.25    37.85               52.0      1274.0          235.0      558.0
# 4   -122.25    37.85               52.0      1627.0          280.0      565.0
#
#   households median_income median_house_value ocean_proximity
# 0      126.0        8.3252           452600.0        NEAR BAY
# 1     1138.0        8.3014           358500.0        NEAR BAY
# 2      177.0        7.2574           352100.0        NEAR BAY
# 3      219.0        5.6431           341300.0        NEAR BAY
# 4      259.0        3.8462           342200.0        NEAR BAY
#   longitude latitude housing_median_age total_rooms total_bedrooms population  \
# 0   -122.23    37.88               41.0       880.0          129.0      322.0
# 1   -122.22    37.86               21.0      7099.0         1106.0     2401.0
# 2   -122.24    37.85               52.0      1467.0          190.0      496.0
# 3   -122.25    37.85               52.0      1274.0          235.0      558.0
# 4   -122.25    37.85               52.0      1627.0          280.0      565.0
#
#   households median_income median_house_value ocean_proximity
# 0      126.0        8.3252           452600.0        NEAR BAY
# 1     1138.0        8.3014           358500.0        NEAR BAY
# 2      177.0        7.2574           352100.0        NEAR BAY
# 3      219.0        5.6431           341300.0        NEAR BAY
nSkipping line 762: expected 10 fields, saw 20\nSkipping line 763: expected 10 fields, saw 17\nSkipping line 764: expected 10 fields, saw 15\nSkipping line 765: expected 10 fields, saw 20\nSkipping line 768: expected 10 fields, saw 11\nSkipping line 773: expected 10 fields, saw 21\nSkipping line 785: expected 10 fields, saw 14\nSkipping line 786: expected 10 fields, saw 11\nSkipping line 787: expected 10 fields, saw 29\nSkipping line 788: expected 10 fields, saw 12\nSkipping line 789: expected 10 fields, saw 19\nSkipping line 790: expected 10 fields, saw 42\nSkipping line 792: expected 10 fields, saw 24\nSkipping line 793: expected 10 fields, saw 16\nSkipping line 794: expected 10 fields, saw 13\nSkipping line 796: expected 10 fields, saw 12\nSkipping line 801: expected 10 fields, saw 27\nSkipping line 802: expected 10 fields, saw 11\nSkipping line 814: expected 10 fields, saw 15\nSkipping line 817: expected 10 fields, saw 11\nSkipping line 818: expected 10 fields, saw 21\nSkipping line 819: expected 10 fields, saw 12\nSkipping line 820: expected 10 fields, saw 20\nSkipping line 823: expected 10 fields, saw 13\nSkipping line 825: expected 10 fields, saw 67\nSkipping line 826: expected 10 fields, saw 14\nSkipping line 827: expected 10 fields, saw 28\nSkipping line 828: expected 10 fields, saw 16\nSkipping line 830: expected 10 fields, saw 17\nSkipping line 831: expected 10 fields, saw 15\nSkipping line 832: expected 10 fields, saw 18\nSkipping line 834: expected 10 fields, saw 11\nSkipping line 835: expected 10 fields, saw 21\nSkipping line 846: expected 10 fields, saw 11\nSkipping line 847: expected 10 fields, saw 17\nSkipping line 851: expected 10 fields, saw 13\nSkipping line 852: expected 10 fields, saw 44\nSkipping line 853: expected 10 fields, saw 27\nSkipping line 854: expected 10 fields, saw 23\nSkipping line 855: expected 10 fields, saw 26\nSkipping line 858: expected 10 fields, saw 11\nSkipping line 859: expected 10 fields, saw 47\nSki ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-65d52402fd6d> in <module>()
#      51 print( housing_dataframe.head() )
#      52
# ---> 53 housing_dataframe.hist(bins=50, figsize=(20, 15))
#      54
#      55
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2406     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2407                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2408                           layout=layout)
#    2409     _axes = _flatten(axes)
#    2410
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     236
#     237     # Create first subplot separately, so we can share it if requested
# --> 238     ax0 = fig.add_subplot(nrows, ncols, 1, **subplot_kw)
#     239
#     240     if sharex:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      58                     raise ValueError(
#      59                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 60                         ).format(maxn=rows*cols, num=num))
#      61                 self._subplotspec = GridSpec(
#      62                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 0, not 1
